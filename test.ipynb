# %%
import torch
print(torch.cuda.is_available())  # Should now print 'True'
print(torch.cuda.get_device_name(0))  # Should print 'Quadro P1000'
# Out:
# True
# Quadro P1000

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.5 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB 47.1 MB/s eta 0:01:00
#    ---------------------------------------- 0.0/2.8 GB 47.1 MB/s eta 0:01:00
#    ---------------------------------------- 0.0/2.8 GB 47.1 MB/s eta 0:01:00
#    ---------------------------------------- 0.0/2.8 GB 47.1 MB/s eta 0:01:00
#    ---------------------------------------- 0.0/2.8 GB 47.1 MB/s eta 0:01:00
#    ---------------------------------------- 0.0/2.8 GB 7.1 MB/s eta 0:06:36
# ...
